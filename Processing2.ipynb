# %%
import pandas as pd
import numpy as np
from tmdbv3api import TMDb
import json
import requests
from tmdbv3api import Movie

# %%
link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2015"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#     Opening  Opening.1                   Title               Director  \
# 0       JAN          2      International Hero        Sanjay Niranjan
# 1       JAN          2  Mumbai Can Dance Saala       Sachindra Sharma
# 2       JAN          2            Take It Easy        Sunil Prem Vyas
# 3       JAN          9                   Tevar            Amit Sharma
# 4       JAN         16                   Alone          Bhushan Patel
# ..      ...        ...                     ...                    ...
# 109     DEC          4            Hate Story 3          Vishal Pandya
# 110     DEC          4                 Kajarya       Madhureeta Anand
# 111     DEC         11       The Silent Heroes           Mahesh Bhatt
# 112     DEC         18         Bajirao Mastani  Sanjay Leela Bhansali
# 113     DEC         18                 Dilwale           Rohit Shetty
#
#                                                   Cast            Genre  \
# ...

# %%
tmdb = TMDb()
tmdb.api_key = '983e7ca75021f7d73509b1b4135dc622'

# %%
tmdb_movie = Movie()

# %%
df_2015 = df[['Title','Director','Cast','Genre']]

# %%
df_2015
# Out:
#                       Title               Director  \
# 0        International Hero        Sanjay Niranjan
# 1    Mumbai Can Dance Saala       Sachindra Sharma
# 2              Take It Easy        Sunil Prem Vyas
# 3                     Tevar            Amit Sharma
# 4                     Alone          Bhushan Patel
# ..                      ...                    ...
# 109            Hate Story 3          Vishal Pandya
# 110                 Kajarya       Madhureeta Anand
# 111       The Silent Heroes           Mahesh Bhatt
# 112         Bajirao Mastani  Sanjay Leela Bhansali
# 113                 Dilwale           Rohit Shetty
#
#                                                   Cast            Genre
# 0             Nakul Vaid, Jatin Grewal, Gurleen Choter            Drama
# 1    Ashima Sharma, Prashant Narayanan, Aditya Panc...         Thriller
# 2    Vikram Gokhale, Dipannita Sharma, Raj Zutshi, ...            Drama
# ...

# %%
df_2015 = df_2015.rename(columns={'Title':'title'})

# %%
df_2015
# Out:
#                       title               Director  \
# 0        International Hero        Sanjay Niranjan
# 1    Mumbai Can Dance Saala       Sachindra Sharma
# 2              Take It Easy        Sunil Prem Vyas
# 3                     Tevar            Amit Sharma
# 4                     Alone          Bhushan Patel
# ..                      ...                    ...
# 109            Hate Story 3          Vishal Pandya
# 110                 Kajarya       Madhureeta Anand
# 111       The Silent Heroes           Mahesh Bhatt
# 112         Bajirao Mastani  Sanjay Leela Bhansali
# 113                 Dilwale           Rohit Shetty
#
#                                                   Cast            Genre
# 0             Nakul Vaid, Jatin Grewal, Gurleen Choter            Drama
# 1    Ashima Sharma, Prashant Narayanan, Aditya Panc...         Thriller
# 2    Vikram Gokhale, Dipannita Sharma, Raj Zutshi, ...            Drama
# ...

# %%
df_2015 = df_2015.rename(columns={'Director':'directors'})
df_2015 = df_2015.rename(columns={'Cast':'actors'})
df_2015 = df_2015.rename(columns={'Genre':'genre'})

# %%
df_2015
# Out:
#                       title              directors  \
# 0        International Hero        Sanjay Niranjan
# 1    Mumbai Can Dance Saala       Sachindra Sharma
# 2              Take It Easy        Sunil Prem Vyas
# 3                     Tevar            Amit Sharma
# 4                     Alone          Bhushan Patel
# ..                      ...                    ...
# 109            Hate Story 3          Vishal Pandya
# 110                 Kajarya       Madhureeta Anand
# 111       The Silent Heroes           Mahesh Bhatt
# 112         Bajirao Mastani  Sanjay Leela Bhansali
# 113                 Dilwale           Rohit Shetty
#
#                                                 actors            genre
# 0             Nakul Vaid, Jatin Grewal, Gurleen Choter            Drama
# 1    Ashima Sharma, Prashant Narayanan, Aditya Panc...         Thriller
# 2    Vikram Gokhale, Dipannita Sharma, Raj Zutshi, ...            Drama
# ...

# %%
df_2015['directors'] = df_2015['directors'].replace(np.nan, 'unknown')
df_2015['actors'] = df_2015['actors'].replace(np.nan, 'unknown')
df_2015['genre'] = df_2015['genre'].replace(np.nan, 'unknown')

# %%
df_2015['title'] = df_2015['title'].str.lower()

# %%
df_2015['comb'] = df_2015['directors'] + ' ' + df_2015['actors'] + ' '+ df_2015['genre']

# %%
df_2015
# Out:
#                       title              directors  \
# 0        international hero        Sanjay Niranjan
# 1    mumbai can dance saala       Sachindra Sharma
# 2              take it easy        Sunil Prem Vyas
# 3                     tevar            Amit Sharma
# 4                     alone          Bhushan Patel
# ..                      ...                    ...
# 109            hate story 3          Vishal Pandya
# 110                 kajarya       Madhureeta Anand
# 111       the silent heroes           Mahesh Bhatt
# 112         bajirao mastani  Sanjay Leela Bhansali
# 113                 dilwale           Rohit Shetty
#
#                                                 actors            genre  \
# 0             Nakul Vaid, Jatin Grewal, Gurleen Choter            Drama
# 1    Ashima Sharma, Prashant Narayanan, Aditya Panc...         Thriller
# 2    Vikram Gokhale, Dipannita Sharma, Raj Zutshi, ...            Drama
# ...

# %%
link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2016"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#     Opening  Opening.1              Title            Director  \
# 0       JAN          8              Wazir       Bejoy Nambiar
# 1       JAN         15     Chalk n Duster      Jayant Gilatar
# 2       JAN         15  Rebellious Flower       Krishan Hooda
# 3       JAN         22            Airlift  Raja Krishna Menon
# 4       JAN         22              Jugni     Shefali Bhushan
# ..      ...        ...                ...                 ...
# 119     NOV         25     Moh Maya Money    Munish Bharadwaj
# 120     DEC          2          Kahaani 2         Sujoy Ghosh
# 121     DEC          9            Befikre       Aditya Chopra
# 122     DEC         16       Wajah Tum Ho       Vishal Pandya
# 123     DEC         23             Dangal       Nitesh Tiwari
#
#                                                   Cast          Genre  \
# 0    Amitabh Bachchan, Farhan Akhtar, Aditi Rao Hyd...       Thriller
# 1    Shabana Azmi, Juhi Chawla, Divya Dutta, Zarina...          Drama
# ...

# %%
df_2016 = df[['Title','Director','Cast','Genre']]

# %%
df_2016
# Out:
#                  Title            Director  \
# 0                Wazir       Bejoy Nambiar
# 1       Chalk n Duster      Jayant Gilatar
# 2    Rebellious Flower       Krishan Hooda
# 3              Airlift  Raja Krishna Menon
# 4                Jugni     Shefali Bhushan
# ..                 ...                 ...
# 119     Moh Maya Money    Munish Bharadwaj
# 120          Kahaani 2         Sujoy Ghosh
# 121            Befikre       Aditya Chopra
# 122       Wajah Tum Ho       Vishal Pandya
# 123             Dangal       Nitesh Tiwari
#
#                                                   Cast          Genre
# 0    Amitabh Bachchan, Farhan Akhtar, Aditi Rao Hyd...       Thriller
# 1    Shabana Azmi, Juhi Chawla, Divya Dutta, Zarina...          Drama
# 2    Prince Shah, Shashank Singh, Mantra Mugdha, Ki...         Biopic
# 3    Akshay Kumar, Nimrat Kaur, Purab Kohli, Ferena...   War/Thriller
# 4    Sugandha Garg, Siddhant Behl, Sadhana Singh, A...  Musical drama
# ...

# %%
df_2016 = df_2016.rename(columns={'Title':'title'})
df_2016 = df_2016.rename(columns={'Director':'directors'})
df_2016 = df_2016.rename(columns={'Cast':'actors'})
df_2016 = df_2016.rename(columns={'Genre':'genre'})

# %%
df_2016
# Out:
#                  title           directors  \
# 0                Wazir       Bejoy Nambiar
# 1       Chalk n Duster      Jayant Gilatar
# 2    Rebellious Flower       Krishan Hooda
# 3              Airlift  Raja Krishna Menon
# 4                Jugni     Shefali Bhushan
# ..                 ...                 ...
# 119     Moh Maya Money    Munish Bharadwaj
# 120          Kahaani 2         Sujoy Ghosh
# 121            Befikre       Aditya Chopra
# 122       Wajah Tum Ho       Vishal Pandya
# 123             Dangal       Nitesh Tiwari
#
#                                                 actors          genre
# 0    Amitabh Bachchan, Farhan Akhtar, Aditi Rao Hyd...       Thriller
# 1    Shabana Azmi, Juhi Chawla, Divya Dutta, Zarina...          Drama
# 2    Prince Shah, Shashank Singh, Mantra Mugdha, Ki...         Biopic
# 3    Akshay Kumar, Nimrat Kaur, Purab Kohli, Ferena...   War/Thriller
# 4    Sugandha Garg, Siddhant Behl, Sadhana Singh, A...  Musical drama
# ...

# %%
df_2016['directors'] = df_2016['directors'].replace(np.nan, 'unknown')
df_2016['actors'] = df_2016['actors'].replace(np.nan, 'unknown')
df_2016['genre'] = df_2016['genre'].replace(np.nan, 'unknown')

# %%
df_2016['title'] = df_2016['title'].str.lower()

# %%
df_2016['comb'] = df_2016['directors'] + ' ' + df_2016['actors'] + ' '+ df_2016['genre']

# %%
df_2016
# Out:
#                  title           directors  \
# 0                wazir       Bejoy Nambiar
# 1       chalk n duster      Jayant Gilatar
# 2    rebellious flower       Krishan Hooda
# 3              airlift  Raja Krishna Menon
# 4                jugni     Shefali Bhushan
# ..                 ...                 ...
# 119     moh maya money    Munish Bharadwaj
# 120          kahaani 2         Sujoy Ghosh
# 121            befikre       Aditya Chopra
# 122       wajah tum ho       Vishal Pandya
# 123             dangal       Nitesh Tiwari
#
#                                                 actors          genre  \
# 0    Amitabh Bachchan, Farhan Akhtar, Aditi Rao Hyd...       Thriller
# 1    Shabana Azmi, Juhi Chawla, Divya Dutta, Zarina...          Drama
# 2    Prince Shah, Shashank Singh, Mantra Mugdha, Ki...         Biopic
# 3    Akshay Kumar, Nimrat Kaur, Purab Kohli, Ferena...   War/Thriller
# 4    Sugandha Garg, Siddhant Behl, Sadhana Singh, A...  Musical drama
# ...

# %%
link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2017"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#     Opening  Opening.1             Title                Director  \
# 0       JAN       13.0        Haraamkhor            Shlok Sharma
# 1       JAN       13.0          Ok Jaanu               Shaad Ali
# 2       JAN       20.0     Coffee with D           Vishal Mishra
# 3       JAN       25.0            Kaabil            Sanjay Gupta
# 4       JAN       25.0             Raees          Rahul Dholakia
# ..      ...        ...               ...                     ...
# 120     DEC        8.0    Fukrey Returns   Mrighdeep Singh Lamba
# 121     DEC        8.0         Game Over  Paresh Vinodray Savani
# 122     DEC        8.0   Sallu Ki Shaadi   Mohammad Israr Ansari
# 123     DEC       15.0  Monsoon Shootout              Amit Kumar
# 124     DEC       22.0   Tiger Zinda Hai         Ali Abbas Zafar
#
#                                                   Cast              Genre  \
# 0                 Nawazuddin Siddiqui, Shweta Tripathi      Comedy, Crime
# ...

# %%
df_2017 = df[['Title','Director','Cast','Genre']]

# %%
df_2017
# Out:
#                 Title                Director  \
# 0          Haraamkhor            Shlok Sharma
# 1            Ok Jaanu               Shaad Ali
# 2       Coffee with D           Vishal Mishra
# 3              Kaabil            Sanjay Gupta
# 4               Raees          Rahul Dholakia
# ..                ...                     ...
# 120    Fukrey Returns   Mrighdeep Singh Lamba
# 121         Game Over  Paresh Vinodray Savani
# 122   Sallu Ki Shaadi   Mohammad Israr Ansari
# 123  Monsoon Shootout              Amit Kumar
# 124   Tiger Zinda Hai         Ali Abbas Zafar
#
#                                                   Cast              Genre
# 0                 Nawazuddin Siddiqui, Shweta Tripathi      Comedy, Crime
# 1                    Aditya Roy Kapur, Shraddha Kapoor     Romance, Drama
# 2                          Sunil Grover, Zakir Hussain      Comedy, Crime
# 3                          Hrithik Roshan, Yami Gautam   Action, Thriller
# ...

# %%
df_2017 = df_2017.rename(columns={'Title':'title'})
df_2017 = df_2017.rename(columns={'Director':'directors'})
df_2017 = df_2017.rename(columns={'Cast':'actors'})
df_2017 = df_2017.rename(columns={'Genre':'genre'})

# %%
df_2017
# Out:
#                 title               directors  \
# 0          Haraamkhor            Shlok Sharma
# 1            Ok Jaanu               Shaad Ali
# 2       Coffee with D           Vishal Mishra
# 3              Kaabil            Sanjay Gupta
# 4               Raees          Rahul Dholakia
# ..                ...                     ...
# 120    Fukrey Returns   Mrighdeep Singh Lamba
# 121         Game Over  Paresh Vinodray Savani
# 122   Sallu Ki Shaadi   Mohammad Israr Ansari
# 123  Monsoon Shootout              Amit Kumar
# 124   Tiger Zinda Hai         Ali Abbas Zafar
#
#                                                 actors              genre
# 0                 Nawazuddin Siddiqui, Shweta Tripathi      Comedy, Crime
# 1                    Aditya Roy Kapur, Shraddha Kapoor     Romance, Drama
# 2                          Sunil Grover, Zakir Hussain      Comedy, Crime
# 3                          Hrithik Roshan, Yami Gautam   Action, Thriller
# ...

# %%
df_2017['directors'] = df_2017['directors'].replace(np.nan, 'unknown')
df_2017['actors'] = df_2017['actors'].replace(np.nan, 'unknown')
df_2017['genre'] = df_2017['genre'].replace(np.nan, 'unknown')

# %%
df_2017['title'] = df_2017['title'].str.lower()

# %%
df_2017['comb'] = df_2017['directors'] + ' ' + df_2017['actors'] + ' '+ df_2017['genre']

# %%
df_2017
# Out:
#                 title               directors  \
# 0          haraamkhor            Shlok Sharma
# 1            ok jaanu               Shaad Ali
# 2       coffee with d           Vishal Mishra
# 3              kaabil            Sanjay Gupta
# 4               raees          Rahul Dholakia
# ..                ...                     ...
# 120    fukrey returns   Mrighdeep Singh Lamba
# 121         game over  Paresh Vinodray Savani
# 122   sallu ki shaadi   Mohammad Israr Ansari
# 123  monsoon shootout              Amit Kumar
# 124   tiger zinda hai         Ali Abbas Zafar
#
#                                                 actors              genre  \
# 0                 Nawazuddin Siddiqui, Shweta Tripathi      Comedy, Crime
# 1                    Aditya Roy Kapur, Shraddha Kapoor     Romance, Drama
# 2                          Sunil Grover, Zakir Hussain      Comedy, Crime
# 3                          Hrithik Roshan, Yami Gautam   Action, Thriller
# ...

# %%
my_df = df_2015.append(df_2016,ignore_index=True)

# %%
my_df
# Out:
#                       title         directors  \
# 0        international hero   Sanjay Niranjan
# 1    mumbai can dance saala  Sachindra Sharma
# 2              take it easy   Sunil Prem Vyas
# 3                     tevar       Amit Sharma
# 4                     alone     Bhushan Patel
# ..                      ...               ...
# 233          moh maya money  Munish Bharadwaj
# 234               kahaani 2       Sujoy Ghosh
# 235                 befikre     Aditya Chopra
# 236            wajah tum ho     Vishal Pandya
# 237                  dangal     Nitesh Tiwari
#
#                                                 actors            genre  \
# 0             Nakul Vaid, Jatin Grewal, Gurleen Choter            Drama
# 1    Ashima Sharma, Prashant Narayanan, Aditya Panc...         Thriller
# 2    Vikram Gokhale, Dipannita Sharma, Raj Zutshi, ...            Drama
# 3    Arjun Kapoor, Sonakshi Sinha, Raj Babbar, Mano...  Action, Romance
# ...

# %%
my_df = my_df.append(df_2017,ignore_index=True)

# %%
my_df
# Out:
#                       title               directors  \
# 0        international hero         Sanjay Niranjan
# 1    mumbai can dance saala        Sachindra Sharma
# 2              take it easy         Sunil Prem Vyas
# 3                     tevar             Amit Sharma
# 4                     alone           Bhushan Patel
# ..                      ...                     ...
# 358          fukrey returns   Mrighdeep Singh Lamba
# 359               game over  Paresh Vinodray Savani
# 360         sallu ki shaadi   Mohammad Israr Ansari
# 361        monsoon shootout              Amit Kumar
# 362         tiger zinda hai         Ali Abbas Zafar
#
#                                                 actors              genre  \
# 0             Nakul Vaid, Jatin Grewal, Gurleen Choter              Drama
# 1    Ashima Sharma, Prashant Narayanan, Aditya Panc...           Thriller
# 2    Vikram Gokhale, Dipannita Sharma, Raj Zutshi, ...              Drama
# ...

# %%
old_df = pd.read_csv('data.csv')

# %%
old_df
# Out:
#                                   title  \
# 0                                albela
# 1     lagaan: once upon a time in india
# 2              meri biwi ka jawab nahin
# 3                hum tumhare hain sanam
# 4                            one 2 ka 4
# ...                                 ...
# 1279               shuruaat ka interval
# 1280                   trip to bhangarh
# 1281                           zed plus
# 1282                    gollu aur pappu
# 1283                                zid
#
#                                               directors  \
# 0                                         Deepak Sareen
# 1                                    Ashutosh Gowariker
# 2                          Pankaj Parashar   S.M. Iqbal
# 3                                         K.S. Adiyaman
# 4                                     Shashilal K. Nair
# ...                                                 ...
# 1279  Aarti S. Bagdi   Amrit Raj Gupta   Krishan Hoo...
# ...

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                                   title                     directors  \
# 0                                albela                 Deepak Sareen
# 1     lagaan: once upon a time in india            Ashutosh Gowariker
# 2              meri biwi ka jawab nahin  Pankaj Parashar   S.M. Iqbal
# 3                hum tumhare hain sanam                 K.S. Adiyaman
# 4                            one 2 ka 4             Shashilal K. Nair
# ...                                 ...                           ...
# 1642                     fukrey returns         Mrighdeep Singh Lamba
# 1643                          game over        Paresh Vinodray Savani
# 1644                    sallu ki shaadi         Mohammad Israr Ansari
# 1645                   monsoon shootout                    Amit Kumar
# 1646                    tiger zinda hai               Ali Abbas Zafar
#
#                                                  actors  \
# 0     Govinda   Aishwarya Rai Bachchan   Jackie Shro...
# ...

# %%
final_df.isna().sum()
# Out:
# title        1
# directors    0
# actors       0
# genre        2
# comb         2
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# title        0
# directors    0
# actors       0
# genre        0
# comb         0
# dtype: int64

# %%
final_df.to_csv('final_data.csv',index=False)
